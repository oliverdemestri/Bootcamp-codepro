# %%
info_persona = {} 
info_persona ["Nombre"]=input('Ingrese su nombre')
print(info_persona)
info_persona ["Apellido"]=input('Ingrese su Apellido')
print(info_persona)
info_persona ["Sexo"]=input('ingrese su Sexo')
print(info_persona)
info_persona ["Edad"]=input('Ingrese su Edad')
print(info_persona)
info_persona ["Departamento"]=input('Ingrese su Departamento')
print(info_persona)
info_persona ["Ciudad"]=input('Ingrese su ciudad')
print(info_persona)
# Out:
# {'Nombre': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x0000015F7A064C10>>}
# {'Nombre': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x0000015F7A064C10>>, 'Apellido': 'josias'}

# %% [markdown]
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
dato_Persona = {}


opcion_del_usuario = input("Ingrese su Opcion")
if dato_Persona == '1':
    clave_del_usuario = input("ingrese su clave")
    valor_del_usuario = input('ingrese su clave')
    dato_Persona[clave_del_usuario] = valor_del_usuario
print(opcion_del_usuario)
# Out:
# 1

# %%
agenda = {"Emergencias": "911", "bomberos": "120"}
def crear_agenda(agenda):
    nombre = input('ingrese su nombre')
    numero = input('ingrese su numero')
def ver_agenda(): s
