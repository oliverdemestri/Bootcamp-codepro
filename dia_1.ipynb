# %%
#Information
name = "Oliver"
age = 19
city = "Asuncion"
#Print
print(f"My name is {name} im {age} years old and i live in {city}")
# Out:
# My name is Oliver im 19 years old and i live in Asuncion

# %%
#Valor de cada variable
cantidadDeManzanas = 19203
cantidadDeNaranjas = 18230
frutasVendidas = 10000

#Suma
cantidadDeFrutas = cantidadDeNaranjas + cantidadDeManzanas
print(f"La cantidad de frutas es:{cantidadDeFrutas}")

#resta
frutasRestantes = cantidadDeFrutas - frutasVendidas
print(f"La cantidad de frutas restantes es:{frutasRestantes}")
# Out:
# La cantidad de frutas es:37433
# La cantidad de frutas restantes es:27433

# %%
#Valor de cada variable
cantidadDeManzanas = 19203
cantidadDeNaranjas = 18230
frutasVendidas = 10000

#Operaciones
cantidadDeFrutas = cantidadDeNaranjas + cantidadDeManzanas
frutasRestantes = cantidadDeFrutas - frutasVendidas
print(f"La cantidad de frutas es:{cantidadDeFrutas} \nLa cantidad de frutas restantes es:{frutasRestantes}")
# Out:
# La cantidad de frutas es:37433
# La cantidad de frutas restantes es:27433

# %%
"""Challenge 🤺 - 15m
Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."""
def saludo():
    nombre = "Ivan" 
    apellido = "Brizuela"
    print(f"Hola. Me llamo {nombre} {apellido}. Mucho gusto")
    
saludo()
# Out:
# Hola. Me llamo Ivan Brizuela. Mucho gusto

# %%
dato = input()
print(dato)
# Out:
# nitiidooooooooooooooooo

# %%
caramelos = int(input("cuantos caramelos quieres?"))
chicos = int(input("cuantos chicos serian?"))
caramelosPorChico = caramelos // chicos 
sobrante = caramelos - caramelosPorChico * chicos 
print(f"Cada chico recibira: {caramelosPorChico} y sobran {sobrante} caramelos")
# Out:
# Cada chico recibira: 2 y sobran 1 caramelos

# %%
""" Challenge 🤺 - 20m
Crear una función de un proceso que se les ocurra que tenga varios pasos.
Ejecutar la función 3 veces. """
def preparacionTerere():
    hielo = int(input("Cuanta cantidad de hielo le pondras?"))
    agua = int(input("Cuanta cantidad de agua (en L) le pondras?"))
    yerba = str(input("Que marca de yerba utilizaras?"))
    print(f"Usted se preparo un tereré con {hielo} hielos y {agua} L de agua y en la guampa se encuentra la marca de yerba {yerba}")

preparacionTerere()
preparacionTerere() 
preparacionTerere()
# Out:
# Usted se preparo un tereré con 213 hielos y 12 L de agua y en la guampa se encuentra la marca de yerba 3
# Usted se preparo un tereré con 231 hielos y 32 L de agua y en la guampa se encuentra la marca de yerba 12
# Usted se preparo un tereré con 3 hielos y 123 L de agua y en la guampa se encuentra la marca de yerba 123

# %%
"""Challenge 🤺 - 25m
Escribir una funcion que represente un sistema de pedidos de comida rapida.
La funcion debe recibir como parametros el nombre del producto y el tamaño del pedido.
Al ejecutarse, debe imprimir en pantalla el detalle del pedido de forma clara y ordenada.
Luego, llamar a la funcion pasando los argumentos correspondientes para simular que un cliente realiza un pedido."""

usuarioPedido = input("que deseas pedir hoy")
usuarioCantidad = input("cuantas desea pedir")
def pedidosya(pedido,tamaño):
    print(f"! ya hemos terminado de preparar el pedido ! \n Ha pedido usted {tamaño} {pedido} ")

pedidosya(usuarioPedido,usuarioCantidad)
# Out:
# ! ya hemos terminado de preparar el pedido !
#  Ha pedido usted 2 mondongo

# %%
"""Challenge 🤺 - 10m
🎯 Objetivo:
Practicar variables globales y locales.
Escribir una función calcular_total que reciba el precio de un producto y calcule el total sumando un impuesto global impuesto = 10.
Usa una variable local total para almacenar el resultado e imprime el total.
Llama a la función con distintos precios para probar."""

impuesto = 0.1
precio_user = int(input("dime el precio del producto"))

def calcularTotal(precio):
    calculo = precio * impuesto
    total = precio + calculo
    print(f"El precio total es de: {total}")

calcularTotal (precio_user)
# Out:
# El precio total es de: 110.0
