# %% [markdown]
# Challenge 🤺15 min
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %%
class Animales:
    Especie = 'Ave'
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color
Hipo = Animales ('Hipo','Amarillo')
print(f"Me llamo {Hipo.nombre} y soy un Jeruti de color {Hipo.color}")
# Out:
# Me llamo Hipo y soy un Jeruti de color Amarillo

# %% [markdown]
# Challenge 🤺
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
class Animales:
    Especie = 'ave'
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color  
print(f"Me llamo {Hipo.nombre} y soy un Jeruti de color {Hipo.color}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4         self.nombre = nombre
#       5         self.color = color
# ----> 6 print(f"Me llamo {Hipo.nombre} y soy un Jeruti de color {Hipo.color}")
#
# NameError: name 'Hipo' is not defined

# %%
def __init__(self, mauyar, rasjuñar):
        self.mauyar = mauyar
        self.rasjuñar = rasjuñar
