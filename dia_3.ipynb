# %%
imprimir_palabra = 'palabra'
def palabra():
    print(imprimir_palabra)
palabra()
# Out:
# palabra

# %%
def comparar_letra (letra1, letra2):
  if  letra1 == letra2

# %% [markdown]
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# Imprimir resultado de la funcion.
#
# Pista: cantidad de letras de una palabra en python

# %%
def cantidad_de_letras(palabra, numero):
    caracter = len(palabra)
    if caracter == numero:
        return True
    else:
        return False

cantidad_de_letras(input("ingrese una palabra"), int(input("ingrese un numero")))
# Out:
# True

# %%
palabras_ingresadas = []
for i in range(3):
    palabra = input('ingrese una palabra')
    listas_de_palabras = list(palabra)
    palabras_ingresadas.append(listas_de_palabras)
    print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['w', 'h', 'i', 'v', 'e']]
# [['h', 'o', 'l', 'a'], ['w', 'h', 'i', 'v', 'e'], ['t', 'o', 'r', 't', 'a']]

# %% [markdown]
# Challenge 6 🤺 - 25m
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:

# %%
lista_op = f'''['h', 'o', 'l', 'i', 's']
['h', 'e', 'l', 'l', 'o']
['h', 'a', 'l', 'l', 'o']'''
print(lista_op)

# %%
def obtener_fila_verificada(palabra_a_encontrar, palabras_ingresada):
    cantidad_letras_de_palabra_a_emcontrar =
